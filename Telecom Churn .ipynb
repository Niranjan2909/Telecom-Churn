# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_csv('churn-bigml-80.csv')
df_test = pd.read_csv('churn-bigml-20.csv')

# %%
df_train
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 2661    SC              79        415                 No              No
# 2662    AZ             192        415                 No             Yes
# 2663    WV              68        415                 No              No
# 2664    RI              28        510                 No              No
# 2665    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df_test
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 0      LA             117        408                 No              No
# 1      IN              65        415                 No              No
# 2      NY             161        415                 No              No
# 3      SC             111        415                 No              No
# 4      HI              49        510                 No              No
# ..    ...             ...        ...                ...             ...
# 662    WI             114        415                 No             Yes
# 663    AL             106        408                 No             Yes
# 664    VT              60        415                 No              No
# 665    WV             159        415                 No              No
# 666    CT             184        510                Yes              No
#
#      Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df_train['data'] = 'train'
df_test['data'] = 'test'

# %%
df_total = pd.concat([df_train,df_test],axis = 0)

# %%
df_total.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  ...  Total eve charge  \
# 0             45.07              197.4  ...             16.78
# ...

# %%
df_total.shape
# Out:
# (3333, 21)

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3333 entries, 0 to 666
# Data columns (total 21 columns):
# State                     3333 non-null object
# Account length            3333 non-null int64
# Area code                 3333 non-null int64
# International plan        3333 non-null object
# Voice mail plan           3333 non-null object
# Number vmail messages     3333 non-null int64
# Total day minutes         3333 non-null float64
# Total day calls           3333 non-null int64
# Total day charge          3333 non-null float64
# Total eve minutes         3333 non-null float64
# Total eve calls           3333 non-null int64
# Total eve charge          3333 non-null float64
# Total night minutes       3333 non-null float64
# Total night calls         3333 non-null int64
# Total night charge        3333 non-null float64
# Total intl minutes        3333 non-null float64
# Total intl calls          3333 non-null int64
# Total intl charge         3333 non-null float64
# ...

# %%
df_total.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# data                      0
# dtype: int64

# %% [markdown]
# #Separating columns to be visualized
# out_cols = list(set(df_total.nunique()[df_total.nunique()<6].keys().tolist()
#                     + df_total.select_dtypes(include='object').columns.tolist()))
# viz_cols = [x for x in df_total.columns if x not in out_cols] + ['Churn']
#
# sns.pairplot(df_total[viz_cols], diag_kind="kde")
# plt.show()

# %%
df_total.nunique()
# Out:
# State                       51
# Account length             212
# Area code                    3
# International plan           2
# Voice mail plan              2
# Number vmail messages       46
# Total day minutes         1667
# Total day calls            119
# Total day charge          1667
# Total eve minutes         1611
# Total eve calls            123
# Total eve charge          1440
# Total night minutes       1591
# Total night calls          120
# Total night charge         933
# Total intl minutes         162
# Total intl calls            21
# Total intl charge          162
# Customer service calls      10
# Churn                        2
# data                         2
# dtype: int64

# %%
sns.pairplot(df_train,diag_kind='kde')

# %%
df_total.corr()
# Out:
#                         Account length  Area code  Number vmail messages  \
# Account length                1.000000  -0.012463              -0.004628
# Area code                    -0.012463   1.000000              -0.001994
# Number vmail messages        -0.004628  -0.001994               1.000000
# Total day minutes             0.006216  -0.008264               0.000778
# Total day calls               0.038470  -0.009646              -0.009548
# Total day charge              0.006214  -0.008264               0.000776
# Total eve minutes            -0.006757   0.003580               0.017562
# Total eve calls               0.019260  -0.011886              -0.005864
# Total eve charge             -0.006745   0.003607               0.017578
# Total night minutes          -0.008955  -0.005825               0.007681
# Total night calls            -0.013176   0.016522               0.007123
# Total night charge           -0.008960  -0.005845               0.007663
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df_total.corr())

# %%
#dropping total day charge, total eve charge, total night charge, tot intl charge due to multi collinearity

df_total.drop(['Total day charge','Total eve charge','Total night charge','Total intl charge','State'], axis=1, inplace = True)

# %%
df_total.head()
# Out:
#    Account length  Area code International plan Voice mail plan  \
# 0             128        415                 No             Yes
# 1             107        415                 No             Yes
# 2             137        415                 No              No
# 3              84        408                Yes              No
# 4              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total eve minutes  Total eve calls  Total night minutes  Total night calls  \
# 0              197.4               99                244.7                 91
# ...

# %%
df_total['Churn'] = df_total['Churn'].replace({True:1,False:0})

# %%
df_total.Churn.astype(int)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 662    0
# 663    0
# 664    0
# 665    0
# 666    0
# Name: Churn, Length: 3333, dtype: int32

# %%
df_total.Churn.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df_total['International plan'] = df_total['International plan'].replace({'No':0,'Yes':1}).astype(int)

# %%
df_total['Voice mail plan'] = df_total['Voice mail plan'].replace({'No':0,'Yes':1}).astype(int)

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3333 entries, 0 to 666
# Data columns (total 16 columns):
# Account length            3333 non-null int64
# Area code                 3333 non-null int64
# International plan        3333 non-null int32
# Voice mail plan           3333 non-null int32
# Number vmail messages     3333 non-null int64
# Total day minutes         3333 non-null float64
# Total day calls           3333 non-null int64
# Total eve minutes         3333 non-null float64
# Total eve calls           3333 non-null int64
# Total night minutes       3333 non-null float64
# Total night calls         3333 non-null int64
# Total intl minutes        3333 non-null float64
# Total intl calls          3333 non-null int64
# Customer service calls    3333 non-null int64
# Churn                     3333 non-null int64
# data                      3333 non-null object
# dtypes: float64(4), int32(2), int64(9), object(1)
# memory usage: 496.6+ KB

# %%
train_set = df_total[df_total['data'] == 'train']
del train_set['data']

# %%
test_set = df_total[df_total['data'] == 'test']
del test_set['data']

# %%
train_set
# Out:
#       Account length  Area code  International plan  Voice mail plan  \
# 0                128        415                   0                1
# 1                107        415                   0                1
# 2                137        415                   0                0
# 3                 84        408                   1                0
# 4                 75        415                   1                0
# ...              ...        ...                 ...              ...
# 2661              79        415                   0                0
# 2662             192        415                   0                1
# 2663              68        415                   0                0
# 2664              28        510                   0                0
# 2665              74        415                   0                1
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1              110
# ...

# %%
test_set
# Out:
#      Account length  Area code  International plan  Voice mail plan  \
# 0               117        408                   0                0
# 1                65        415                   0                0
# 2               161        415                   0                0
# 3               111        415                   0                0
# 4                49        510                   0                0
# ..              ...        ...                 ...              ...
# 662             114        415                   0                1
# 663             106        408                   0                1
# 664              60        415                   0                0
# 665             159        415                   0                0
# 666             184        510                   1                0
#
#      Number vmail messages  Total day minutes  Total day calls  \
# 0                        0              184.5               97
# ...

# %%
np.sum(train_set['Churn'] == 0 )
# Out:
# 2278

# %%
np.sum(train_set['Churn'] == 1)
# Out:
# 388

# %%
sns.countplot(train_set['Churn'])

# %%
train_set.Churn.value_counts()
# Out:
# 0    2278
# 1     388
# Name: Churn, dtype: int64

# %%
388/2666
# Out:
# 0.145536384096024

# %%
2278+2278
# Out:
# 4556

# %%
X = train_set.drop('Churn',axis = 1)
Y = train_set['Churn']

# %%
from imblearn.over_sampling import SMOTE 
sm = SMOTE(random_state = 2)
# Out:
# C:\Users\niran\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# C:\Users\niran\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.ensemble.bagging module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# ...

# %%
X,Y = sm.fit_sample(X,Y)
# Out:
# C:\Users\niran\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
print(X.shape)
print(Y.shape)
# Out:
# (4556, 14)
# (4556,)

# %%
np.sum(Y==1)
# Out:
# 2278

# %%
X.shape
# Out:
# (4556, 14)

# %%
Y
# Out:
# array([0, 0, 0, ..., 1, 1, 1], dtype=int64)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
X=sc.fit_transform(X)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn import model_selection
from sklearn import metrics
from sklearn.model_selection import KFold
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
#from sklearn.ensemble import VotingClassifier

# %%
dt_reg = DecisionTreeClassifier()

# %%
from sklearn.model_selection import GridSearchCV
params={'max_depth':np.arange(1,25), 'criterion':['gini', 'entropy']}
GS=GridSearchCV(dt_reg,params,cv=5,scoring='roc_auc')
GS.fit(X,Y)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features=None,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               presort='deprecated',
#                                               random_state=None,
#                                               splitter='best'),
#              iid='deprecated', n_jobs=None,
# ...

# %%
GS.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 8}

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.ensemble import BaggingClassifier
Lr_model = LogisticRegression()
LR_bag=BaggingClassifier(base_estimator=Lr_model,n_estimators=25,random_state=0)
nb_model = GaussianNB()
NB_bag=BaggingClassifier(base_estimator=nb_model,n_estimators=24,random_state=0)
knn = KNeighborsClassifier(n_neighbors=7, weights='distance')
KNN_bag=BaggingClassifier(base_estimator=knn,n_estimators=80,random_state=0)
DT_reg=DecisionTreeClassifier(max_depth=8,criterion='entropy',random_state=0)
DT_bag=BaggingClassifier(n_estimators=10,random_state=0)
RF=RandomForestClassifier(n_estimators=150,criterion='entropy',random_state=0)
#Boosting models
LR_boost=AdaBoostClassifier(base_estimator=Lr_model,n_estimators=170)
NB_boost=AdaBoostClassifier(base_estimator=nb_model,n_estimators=400)
RF_boost=AdaBoostClassifier(base_estimator=RF,n_estimators=100)
DT_boost=AdaBoostClassifier(n_estimators=100)
GB_boost=GradientBoostingClassifier(n_estimators=100)

# %%
models = []
models.append(('LogisticRegression', Lr_model))
models.append(('LR_bag', LR_bag))
models.append(('Naivebayes', nb_model))
models.append(('bag_nb', NB_bag))
models.append(('knn_model', knn))
models.append(('bag_knn', KNN_bag))
models.append(('DT_regularized', DT_reg))
models.append(('DT_bagged', DT_bag))
models.append(('RandomForest', RF))
models.append(('LR_boost', LR_boost))
models.append(('NB_boost', NB_boost))
models.append(('RF_boost', RF_boost))
models.append(('DT_boost', DT_boost))
models.append(('GB_boost', GB_boost))

models
# Out:
# [('LogisticRegression',
#   LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                      intercept_scaling=1, l1_ratio=None, max_iter=100,
#                      multi_class='auto', n_jobs=None, penalty='l2',
#                      random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                      warm_start=False)),
#  ('LR_bag',
#   BaggingClassifier(base_estimator=LogisticRegression(C=1.0, class_weight=None,
#                                                       dual=False,
#                                                       fit_intercept=True,
#                                                       intercept_scaling=1,
#                                                       l1_ratio=None, max_iter=100,
#                                                       multi_class='auto',
#                                                       n_jobs=None, penalty='l2',
# ...

# %%
results = []
names = []
scoring = 'accuracy'
for name, model in models:
	kfold = model_selection.KFold(n_splits=5,random_state=2)
	cv_results = model_selection.cross_val_score(model, X, Y, cv=kfold, scoring=scoring)
	results.append(cv_results)
	names.append(name)
	msg = "%s: %f (%f)" % (name, np.mean(cv_results), cv_results.var())
	print(msg)
# Out:
# LogisticRegression: 0.694249 (0.001796)
# LR_bag: 0.692493 (0.001891)
# Naivebayes: 0.696894 (0.001221)
# bag_nb: 0.694919 (0.001109)
# knn_model: 0.854716 (0.011735)
# bag_knn: 0.857789 (0.010536)
# DT_regularized: 0.925808 (0.000153)
# DT_bagged: 0.942493 (0.000012)
# RandomForest: 0.958299 (0.000175)
# LR_boost: 0.678882 (0.002814)
# NB_boost: 0.490312 (0.025751)
# RF_boost: 0.955447 (0.000221)
# DT_boost: 0.900796 (0.000876)
# GB_boost: 0.941397 (0.000101)

# %%
results = []
names = []
scoring = 'recall'
for name, model in models:
    kfold = model_selection.KFold(n_splits=5)
    cv_results = model_selection.cross_val_score(model, X, Y, cv=kfold, scoring=scoring)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, np.mean(cv_results), cv_results.var())
    print(msg)
# Out:
# LogisticRegression: 0.736498 (0.005511)
# LR_bag: 0.739289 (0.006160)
# Naivebayes: 0.777384 (0.001829)
# bag_nb: 0.776576 (0.002030)
# knn_model: 0.982965 (0.000124)
# bag_knn: 0.981208 (0.000120)
# DT_regularized: 0.860836 (0.001764)
# DT_bagged: 0.890200 (0.001656)
# RandomForest: 0.913812 (0.002499)
# LR_boost: 0.724218 (0.007668)
# NB_boost: 0.405510 (0.009653)
# RF_boost: 0.915002 (0.002242)
# DT_boost: 0.766265 (0.020199)
# GB_boost: 0.877153 (0.004121)

# %%
from sklearn.metrics import roc_curve, auc

# %%
kfold = KFold(n_splits=5,shuffle=True,random_state=0)
for name, model in models:
    roc_auc = []
    for train, test in kfold.split(X,Y):
        Xtrain, Xtest = X[train,:],X[test,:] 
        Ytrain,Ytest = Y[train], Y[test]
        model.fit(Xtrain,Ytrain)
        Y_predict = model.predict(Xtest)
        #cm = metrics.confusion_matrix(Ytest, Y_predict)
        fpr,tpr, _ =roc_curve(Ytest,Y_predict)
        roc_auc.append(auc(fpr, tpr))
    print('AUC scores: %0.2f (+/- %0.5f) [%s]' %(np.mean(roc_auc), np.var(roc_auc,ddof = 1), name))
# Out:
# AUC scores: 0.77 (+/- 0.00016) [LogisticRegression]
# AUC scores: 0.77 (+/- 0.00012) [LR_bag]
# AUC scores: 0.78 (+/- 0.00024) [Naivebayes]
# AUC scores: 0.78 (+/- 0.00018) [bag_nb]
# AUC scores: 0.89 (+/- 0.00011) [knn_model]
# AUC scores: 0.90 (+/- 0.00010) [bag_knn]
# AUC scores: 0.94 (+/- 0.00011) [DT_regularized]
# AUC scores: 0.96 (+/- 0.00004) [DT_bagged]
# AUC scores: 0.96 (+/- 0.00002) [RandomForest]
# AUC scores: 0.77 (+/- 0.00016) [LR_boost]
# AUC scores: 0.55 (+/- 0.00002) [NB_boost]
# AUC scores: 0.96 (+/- 0.00003) [RF_boost]
# AUC scores: 0.91 (+/- 0.00005) [DT_boost]
# AUC scores: 0.95 (+/- 0.00001) [GB_boost]
